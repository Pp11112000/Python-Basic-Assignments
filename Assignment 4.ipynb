# %%
1. What exactly is []?

Ans --->

# %% [markdown]
# Basically square brackets ([ ]) are used to notify as a list.
#
# eg:-
#
# mylist = [1,2,3,4],  [ ] = emptylist

# %%
2. In a list of values stored in a variable called spam, 
how would you assign the value 'hello' as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)

Ans --->

# %%
spam = [2, 4, 6, 8, 10]

# %%
spam[2] = 'hello'

# %%
spam
# Out:
# [2, 4, 'hello', 8, 10]

# %%
Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.

# %%
spam = ['a', 'b', 'c', 'd']

# %%
3. What is the value of spam[int(int('3' * 2) / 11)]?

Ans --->

# %%
spam[int(int('3' * 2) / 11)]
# Out:
# 'd'

# %%
4. What is the value of spam[-1]?

Ans --->

# %%
spam[-1]
# Out:
# 'd'

# %%
5. What is the value of spam[:2]?

Ans --->

# %%
spam[:2]
# Out:
# ['a', 'b']

# %%
Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.

# %%
bacon = [3.14, 'cat', 11, 'cat', True]

# %%
6. What is the value of bacon.index('cat')?

Ans --->

# %%
bacon.index('cat')
# Out:
# 1

# %%
7. How does bacon.append(99) change the look of the list value in bacon?

Ans --->

# %%
bacon.append(99)

# %%
bacon
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %%
8. How does bacon.remove('cat') change the look of the list in bacon?

Ans --->

# %%
bacon.remove('cat')

# %%
bacon
# Out:
# [3.14, 11, True, 99]

# %%
9. What are the list concatenation and list replication operators?

Ans --->

# %% [markdown]
# For list concatenation + operator is used and for list replication * operator is used.
#
# Below are examples:-

# %%
#1) List Concatenation

mylist0 = [1,2,3]
mylist1 = [4,5,6]

mylist0 + mylist1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#2)  list replication

mylist0 = [1,2,3]

print(mylist0 * 2)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
10. What is difference between the list methods append() and insert()?

Ans --->

# %% [markdown]
# 1) append() :- If we want to add an value at the end of a list then append method comes in the picture.
#
# 2) insert() :- If we want to add an value within a list anywhere then insert method comes in the picture.
#
# Below are examples of both methods:-

# %%
mylist0 = [1,2,3]

# %%
#append()
mylist0.append('hi')

# %%
mylist0
# Out:
# [1, 2, 3, 'hi']

# %%
#inser()
mylist0.insert(1, 'hello')

# %%
mylist0
# Out:
# [1, 'hello', 2, 3, 'hi']

# %%
11. What are the two methods for removing items from a list?

Ans --->

# %% [markdown]
# Two methods for removing items from a list are "remove" and "pop".

# %%
12. Describe how list values and string values are identical.

Ans --->

# %% [markdown]
# Both lists and strings have indexing and slicing, they can be used in loops , can be concatenated as well as replicated.

# %%
13. What's the difference between tuples and lists?

Ans --->

# %% [markdown]
# 1) tuples :-
#
# a) Tuples are immutable in nature.
#
# b) Tuples uses parenthesis ().
#
# c) Tuples has less functionality than the Lists.
#
# d) Tuples have very less in-built methods as compared to lists.
#
# e) It is capable of consuming less memory.
#
# 2) lists :-
#
# a) Lists are mutable in nature.
#
# b) Lists uses square brackets [].
#
# c) Lists has more functionality than the tuples.
#
# d) Lists have more in-built methods as compared to tuples.
#
# e) It is capable of consuming more memory.

# %%
14. How do you type a tuple value that only contains the integer 42?

Ans --->

# %%
mytuple = (42,)

# %%
mytuple
# Out:
# (42,)

# %%
15. How do you get a list value's tuple form? How do you get a tuple value's list form?

Ans --->

# %% [markdown]
# 1) list to tuple:-

# %%
mylist = [1,2,3,4]

a = tuple(mylist)

# %%
a
# Out:
# (1, 2, 3, 4)

# %%
type(a)
# Out:
# tuple

# %% [markdown]
# 2) tuple to list:-

# %%
mytuple = (5,6,7,8)

b = list(mytuple)

# %%
b
# Out:
# [5, 6, 7, 8]

# %%
type(b)
# Out:
# list

# %%
16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?

Ans --->

# %% [markdown]
# They contain refrences to list values.

# %%
17. How do you distinguish between copy.copy() and copy.deepcopy()?

Ans --->

# %% [markdown]
# a) Deep copy:- Deep copy is a process in which the copying process occurs recursively.
# It means first constructing a new collection object and then recursively populating it with copies of the child objects found in the original.
# In case of deep copy, a copy of object is copied in other object. It means that any changes made to a copy of object do not reflect in the original object. In python, this is implemented using “deepcopy()” function.
#
# b) Shallow copy:- A shallow copy means constructing a new collection object and then populating it with references to the child objects found in the original. The copying process does not recurse and therefore won’t create copies of the child objects themselves. In case of shallow copy, a reference of object is copied in other object. It means that any changes made to a copy of object do reflect in the original object. In python, this is implemented using “copy()” function.
