# %%
1. Why are functions advantageous to have in your programs?

Ans --->

# %% [markdown]
# a) It helps to divide the large programs into small groups so that we can read the code, and debug the program faster and better.
#
# b) Python Functions stop us from writing the same logic various times. We can bind the logic in one function and then call the same over and over.
#
# c) Many persons can work on the same program by assigning different functions to each of them.
#
# d) It encourages us to call the same function with different inputs over multiple times.

# %%
2. When does the code in a function run: when it's specified or when it's called?
    
Ans --->

# %% [markdown]
# The code in a function run when it is called.

# %%
3. What statement creates a function?

Ans --->

# %% [markdown]
# To create function def keyword is used in Python. Define a unique name for the function and in parenthesis, you can specify your parameters.
#
# Function block starts with colon(:) symbol.
#
# Syntax:-
#
# def function_name(parameters):

# %%
4. What is the difference between a function and a function call?

Ans --->

# %% [markdown]
# a) funcation ---> A function is a piece of code which enhanced the reusability and modularity of your program. It means that piece of code need not be written again.
#
# b) funcation call --->  A function call means invoking or calling that function. Unless a function is called there is no use of that function.

# %%
5. How many global scopes are there in a Python program? How many local scopes?

Ans --->

# %% [markdown]
# There is one global scope and local scope is created whenever a funcation is called.
#
# There are four scopes in python:-
#
# a) Local scope --> contains a names defined inside a current funcation.
#
# b) Enclosing scope --> contains names defined inside any and all enclosed functions.
#
# c) Global scope -->  contains names defined at the top level of the script or module.
#
# d) Build - in --> contains names built_in to the python language.

# %%
6. What happens to variables in a local scope when the function call returns?

Ans --->

# %% [markdown]
# When a function returns, the local scope is destroyed, and all the variables in it are forgotten.

# %%
7. What is the concept of a return value? Is it possible to have a return value in an expression?

Ans --->

# %% [markdown]
# A return value is used to end the execution of the function call and “returns” the result (value of the expression following the return keyword) to the caller. Yes it is possible to have return value in an expression.

# %%
8. If a function does not have a return statement, what is the return value of a call to that function?

Ans --->

# %% [markdown]
# If a function doesn't specify a return value, it returns None.

# %%
9. How do you make a function variable refer to the global variable?

Ans --->

# %% [markdown]
# A global statement will force a variable in a function to refer to the global variable.

# %%
10. What is the data type of None?

Ans --->

# %% [markdown]
# The data type of None is NoneType.

# %%
11. What does the sentence import areallyourpetsnamederic do?

Ans --->

# %% [markdown]
# There is no module of name areallyourpetsnamederic. It throws below error:

# %%
import areallyourpetsnamederic
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-b1ea9cb2228f> in <module>
# ----> 1 import areallyourpetsnamederic
#
# ModuleNotFoundError: No module named 'areallyourpetsnamederic'

# %%
12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

Ans --->

# %% [markdown]
# After importing spam module this bacon() feature is called as below:
#
# spam.bacon()

# %%
13. What can you do to save a programme from crashing if it encounters an error?

Ans --->

# %% [markdown]
# include try and except block in your code to avoid from crashing.

# %%
14. What is the purpose of the try clause? What is the purpose of the except clause?

Ans --->

# %% [markdown]
# Whenever we want to write a long code and in between code
# if we are not aware about writen code is totally correct or wroung, so as a safer side we have to use try and except clause.
#
# So basically,
#
# try :- In try block we have to write a code which we are not sure that it will run or not.
#
# except :- In except block we have to write a code that will only run when try block fails.
